# %%
# Gonzalez+07 table 1 https://iopscience.iop.org/article/10.1086/519729/pdf
# Gonzalez+05 table 4 https://iopscience.iop.org/article/10.1086/425896/pdf
Gonzalez_dict = {
#      Gonzelez+07 (f_BCG+ICL=L_BCGICL/(L_BCGICL+L_gal))
#     ['z','M500','M_BCG+ICL','M_BCG+ICL_err','Mgal','f_BCG+ICL','f_BCG+ICL_err',
#     Gonzelez+05
#     'Mtot','Mtot_ep','Mtot_em','Mext','Mext_e_stat','Mext_ep_sys','Mext_em_sys',
#     'Mcor','Mcor_e_stat','Mcor_ep_sys','Mcor_em_sys'],
'A0122':[0.1134,14.31,-25.60,0.04,-26.11,0.38,0.04,-25.66,0.06,0.06,-25.56,0.01,0.06,0.06,-22.97,0.03,0.05,0.05],
'A1651':[0.0847,14.87,-25.63,0.10,-26.88,0.24,0.04,-25.84,0.17,0.27,-24.95,0.07,0.48,0.53,-25.21,0.01,0.00,0.02],
'A2400':[0.0880,14.26,-25.08,0.06,-26.10,0.28,0.06,-25.17,0.18,0.32,-24.61,0.04,0.19,0.44,-24.19,0.08,0.17,0.11],
'A2571':[0.1091,14.30,-25.37,0.10,-25.53,0.46,0.10,-25.42,0.15,0.19,-25.11,0.01,0.17,0.22,-23.89,0.02,0.08,0.09],
'A2721':[0.1144,14.63,-25.19,0.02,-26.90,0.17,0.02,-25.20,0.02,0.02,-25.02,0.03,0.04,0.04,-23.14,0.14,0.08,0.08],
'A2730':[0.1201,14.91,-26.04,0.11,-26.49,0.40,0.11,-26.14,0.24,0.30,-26.00,0.03,0.25,0.32,-23.85,0.03,0.19,0.16],
'A2811':[0.1079,14.66,-25.64,0.08,-26.40,0.33,0.08,-25.70,0.22,0.22,-25.53,0.03,0.22,0.23,-23.59,0.03,0.22,0.15],
'A2955':[0.0943,13.19,-25.16,0.06,-24.96,0.55,0.06,-25.31,0.08,0.08,-25.22,0.01,0.08,0.08,-22.61,0.03,0.09,0.08],
'A2969':[0.1259,14.85,-25.58,0.08,-26.62,0.28,0.08,-25.58,0.26,0.44,-25.35,0.03,0.27,0.49,-23.80,0.08,0.21,0.18],
'A2984':[0.1042,13.84,-25.63,0.05,-25.51,0.53,0.05,-25.87,0.01,0.09,-25.79,0.01,0.01,0.09,-23.04,0.02,0.01,0.04],
'A3112':[0.0753,14.79,-25.76,0.03,-26.96,0.25,0.03,-25.82,0.07,0.07,-25.74,0.01,0.06,0.06,-22.95,0.04,0.16,0.17],
'A3166':[0.1174,12.56,-24.55,0.06,-23.99,0.63,0.06,-24.73,0.07,0.08,-24.65,0.02,0.07,0.08,-21.92,0.04,0.08,0.08],
'A3705':[0.0895,14.89,-24.37,0.02,-26.53,0.12,0.02,-24.38,0.04,0.08,-24.27,0.01,0.03,0.00,-21.85,0.07,0.18,0.62],
'A3727':[0.1159,14.09,-24.97,0.06,-25.83,0.31,0.06,-25.14,0.17,0.19,-24.97,0.05,0.19,0.21,-23.07,0.03,0.05,0.04],
'A3809':[0.0623,13.99,-24.69,0.04,-25.38,0.35,0.04,-24.76,0.07,0.08,-23.85,0.03,0.13,0.16,-24.14,0.03,0.02,0.02],
'A3920':[0.1268,13.63,-25.06,0.04,-25.27,0.45,0.04,-25.08,0.02,0.04,-24.80,0.01,0.01,0.04,-23.48,0.01,0.07,0.05],
'A4010':[0.0955,14.21,-25.56,0.08,-26.25,0.35,0.08,-25.71,0.21,0.28,-25.56,0.02,0.19,0.28,-23.52,0.06,0.37,0.28],
'AS0084':[0.1080,13.93,-25.38,0.04,-26.16,0.33,0.04,-25.38,0.03,0.05,-25.33,0.01,0.03,0.05,-21.94,0.04,0.08,0.10],
'AS0296':[0.0696,13.80,-25.19,0.04,-25.17,0.51,0.04,-25.05,0.03,0.07,-24.82,0.04,0.16,0.02,-23.25,0.22,0.26,0.72]
                }

# Burke+05 https://academic.oup.com/mnras/article/449/3/2353/1123740
# ICL: light below surface brightness 25 mag/arcsec^2
Burke_dict = {
    'z':[0.187,0.296,0.213,0.224,0.234,0.288,0.313,0.345,0.348,0.352,0.391,0.396,0.399],
'f_ICL':np.array([23.05,17.11,17.97,16.64,12.89,13.02,7.58,7.44,6.44,6.11,3.16,2.69,2.36])*1e-2,
'f_ICL_err':np.array([0.73,0.77,0.73,0.78,1.11,0.23,0.65,0.17,0.10,0.29,0.06,0.10,0.13])*1e-2,   
'M200':np.array([1.04,1.17,1.20,1.76,0.73,1.03,1.26,0.64,1.40,1.13,0.88,2.50,0.96])*1e15,   
'M200_err':np.array([0.07,0.07,0.59,0.18,0.18,0.07,0.06,0.09,0.12,0.10,0.08,0.50,0.14])*1e15,   
}

# %%
z_arr = np.array([0.22,0.34,0.54,0.24,0.38])

logMh_arr = np.array([13.7,13.5,13.4,13.1,12.9])
logMh_low_arr = logMh_arr - np.array([0.5,0.3,0.4,0.3,0.4])
logMh_high_arr = logMh_arr + np.array([0.5,0.4,0.3,0.4,0.3])

fIHL_arr1 = np.array([0.23,0.30,0.19,0.21,0.23])
fIHL_low_arr1 = fIHL_arr1 - np.array([0.05,0.08,0.14,0.05,0.14])
fIHL_high_arr1 = fIHL_arr1 + np.array([0.06,0.09,0.07,0.07,0.06])

fIHL_arr2 = np.array([0.21,0.26,0.15,0.21,0.15])
fIHL_low_arr2 = fIHL_arr1 - np.array([0.04,0.06,0.04,0.06,0.05])
fIHL_high_arr2 = fIHL_arr1 + np.array([0.06,0.06,0.05,0.04,0.07])

# %%
fig, ax = plt.subplots(1,1,figsize=(11,6))

# Purcell
data = np.loadtxt('Illustris_frac/Purcell08_med.txt', delimiter=',')
data_h = np.loadtxt('Illustris_frac/Purcell08_68high.txt', delimiter=',')
data_l = np.loadtxt('Illustris_frac/Purcell08_68low.txt', delimiter=',')
ax.fill_between(10**data[:,0],
                 10**np.interp(data[:,0],data_l[:,0],data_l[:,1]),
                 10**np.interp(data[:,0],data_h[:,0],data_h[:,1]),
                         facecolor='g', alpha=0.15, label=r'Purcell et al. 2007, 2008 ($z=0$)')
data_h = np.loadtxt('Illustris_frac/Purcell08_95high.txt', delimiter=',')
data_l = np.loadtxt('Illustris_frac/Purcell08_95low.txt', delimiter=',')
ax.fill_between(10**data[:,0],
                 10**np.interp(data[:,0],data_l[:,0],data_l[:,1]),
                 10**np.interp(data[:,0],data_h[:,0],data_h[:,1]),
                         facecolor='g', alpha=0.1)

# MW, M31
ax.errorbar([1e12], [0.02], xerr=[1e12*0.1], yerr=[0],
             lw=3, color='C4', label='MW')
ax.errorbar([1.3e12], [0.04], xerr=[1.3e12*0.1], yerr=[0],
             lw=3, color='C5', label='M31')
ax.arrow(1e12, 0.02, 0, -0.02*0.4, width=0.5e11, length_includes_head=True, color='C4', 
         head_width=1.5e11, head_length=0.02*0.2, overhang=0)
ax.arrow(1.3e12, 0.04, 0, -0.04*0.4, width=0.5e11*1.3, length_includes_head=True, color='C5', 
         head_width=1.5e11*1.3, head_length=0.04*0.2, overhang=0)

# Gonzalez
Mh_arr,f_arr,f_low_arr, f_high_arr,z_arr = [],[],[],[],[]
for name,arr in Gonzalez_dict.items():
    z_arr.append(arr[0])
    Mh_arr.append(10**arr[1])
    L_BCGICL_L_tot = arr[5]
    L_ICL_L_BCGICL = 10**(-(arr[10] - arr[7])/2.5)
    f_arr.append(L_BCGICL_L_tot*L_ICL_L_BCGICL)

    L_BCGICL_L_tot = arr[5] - arr[6]
    L_ICL_L_BCGICL = 10**(-((arr[10]+arr[11]+arr[12]) - arr[7])/2.5)
    f_low_arr.append(L_BCGICL_L_tot*L_ICL_L_BCGICL)

    L_BCGICL_L_tot = arr[5] + arr[6]
    L_ICL_L_BCGICL = 10**(-((arr[10]-arr[11]-arr[13]) - arr[7])/2.5)
    f_high_arr.append(L_BCGICL_L_tot*L_ICL_L_BCGICL)

f_arr,f_low_arr, f_high_arr = np.array(f_arr),np.array(f_low_arr), np.array(f_high_arr)
ax.errorbar(Mh_arr, f_arr, yerr=[f_arr - f_low_arr,f_high_arr - f_arr], 
                            fmt='.',capsize=3, mfc=None, markersize=10, color='k',
            label='Gonzalez et al. 2005, 2007 '+r'($z\sim %.2f$)'%(np.median(z_arr)))
# Burke
ax.errorbar(Burke_dict['M200'], Burke_dict['f_ICL'], yerr=Burke_dict['f_ICL_err'], 
                fmt='.',capsize=3, mfc=None, markersize=10, color='k', alpha=0.3,
             label='Burke et al. 2015 '+r'($z\sim %.2f$)'%(np.median(Burke_dict['z'])))


for i,(fmt,mfc,name) in enumerate(zip(['v','s','^','v','s'],[None, None, None, 'none', 'none'],
                                        ['high-M/low-z','high-M/med-z','high-M/high-z',
                                         'low-M/low-z','low-M/med-z'])):
    Mh, Mh_low, Mh_high = 10**logMh_arr[i],10**logMh_low_arr[i],10**logMh_high_arr[i]

        
    f = fIHL_arr1[i]
    f_low = fIHL_low_arr1[i]
    f_high = fIHL_high_arr1[i]
    ax.errorbar([Mh*1.01], [f], xerr=[[Mh-Mh_low],[Mh_high-Mh]],
                   yerr=[[f - f_low],[f_high - f]], alpha=0.8,
                    fmt=fmt,capsize=0, mfc=mfc, markersize=10, c='b', 
                label = name + r' ($z\sim %.2f$)'%z_arr[i])

    f = fIHL_arr2[i]
    f_low = fIHL_low_arr2[i]
    f_high = fIHL_high_arr2[i]            
    ax.errorbar([Mh*0.99], [f], xerr=[[Mh-Mh_low],[Mh_high-Mh]],
                   yerr=[[f - f_low],[f_high - f]], alpha=0.8,
            fmt=fmt,capsize=0, mfc=mfc, markersize=10, c='r')

ax.legend(fontsize=8, bbox_to_anchor=(0.85,0.43))
ax.set_ylim([1e-2,1])
ax.set_xlim([3e11,2e15])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('log (M$_h$ / M$_\odot$)', fontsize=20)
ax.set_ylabel(r"$f_{\rm IHL}$ (%d < r < 100 kpc)"%rcut,
              fontsize=20)
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=15)
ax.set_xticks([1e12, 1e13, 1e14, 1e15])
ax.set_xticklabels(['12','13','14','15'])

# plt.savefig('plots/paperfig/fIHL.pdf',
#             dpi = 200, bbox_inches='tight')
# Out:
# [Text(0, 0, '12'), Text(0, 0, '13'), Text(0, 0, '14'), Text(0, 0, '15')]
